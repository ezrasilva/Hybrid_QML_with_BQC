# %% [markdown]
# # Blind Quantum Computing
#
# Este notebook executa o código de Blind Quantum Computing utilizando Qiskit. O objetivo é demonstrar como rodar experimentos quânticos de forma segura e privada, utilizando um dataset de exemplo (Iris).

# %%
# Instalar dependências
# !pip install matplotlib
# !pip install qiskit qiskit-machine-learning scikit-learn torch
# Out:
# Requirement already satisfied: matplotlib in ./venv/lib/python3.10/site-packages (3.9.2)
# Requirement already satisfied: packaging>=20.0 in ./venv/lib/python3.10/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv/lib/python3.10/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: numpy>=1.23 in ./venv/lib/python3.10/site-packages (from matplotlib) (2.1.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./venv/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pillow>=8 in ./venv/lib/python3.10/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in ./venv/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./venv/lib/python3.10/site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv/lib/python3.10/site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: cycler>=0.10 in ./venv/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: qiskit in ./venv/lib/python3.10/site-packages (1.2.4)
# Requirement already satisfied: qiskit-machine-learning in ./venv/lib/python3.10/site-packages (0.8.3)
# Requirement already satisfied: scikit-learn in ./venv/lib/python3.10/site-packages (1.7.1)
# Requirement already satisfied: torch in ./venv/lib/python3.10/site-packages (2.8.0)
# Requirement already satisfied: typing-extensions in ./venv/lib/python3.10/site-packages (from qiskit) (4.12.2)
# Requirement already satisfied: scipy>=1.5 in ./venv/lib/python3.10/site-packages (from qiskit) (1.14.1)
# Requirement already satisfied: symengine<0.14,>=0.11 in ./venv/lib/python3.10/site-packages (from qiskit) (0.13.0)
# Requirement already satisfied: dill>=0.3 in ./venv/lib/python3.10/site-packages (from qiskit) (0.3.9)
# Requirement already satisfied: stevedore>=3.0.0 in ./venv/lib/python3.10/site-packages (from qiskit) (5.3.0)
# Requirement already satisfied: rustworkx>=0.15.0 in ./venv/lib/python3.10/site-packages (from qiskit) (0.15.1)
# Requirement already satisfied: python-dateutil>=2.8.0 in ./venv/lib/python3.10/site-packages (from qiskit) (2.9.0.post0)
# Requirement already satisfied: numpy<3,>=1.17 in ./venv/lib/python3.10/site-packages (from qiskit) (2.1.0)
# Requirement already satisfied: sympy>=1.3 in ./venv/lib/python3.10/site-packages (from qiskit) (1.13.3)
# Requirement already satisfied: setuptools>=40.1 in ./venv/lib/python3.10/site-packages (from qiskit-machine-learning) (59.6.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./venv/lib/python3.10/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: joblib>=1.2.0 in ./venv/lib/python3.10/site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: networkx in ./venv/lib/python3.10/site-packages (from torch) (3.3)
# Requirement already satisfied: triton==3.4.0 in ./venv/lib/python3.10/site-packages (from torch) (3.4.0)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in ./venv/lib/python3.10/site-packages (from torch) (11.3.3.83)
# Requirement already satisfied: filelock in ./venv/lib/python3.10/site-packages (from torch) (3.18.0)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in ./venv/lib/python3.10/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in ./venv/lib/python3.10/site-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in ./venv/lib/python3.10/site-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in ./venv/lib/python3.10/site-packages (from torch) (1.13.1.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in ./venv/lib/python3.10/site-packages (from torch) (2.27.3)
# Requirement already satisfied: fsspec in ./venv/lib/python3.10/site-packages (from torch) (2025.7.0)
# Requirement already satisfied: jinja2 in ./venv/lib/python3.10/site-packages (from torch) (3.1.6)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in ./venv/lib/python3.10/site-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in ./venv/lib/python3.10/site-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in ./venv/lib/python3.10/site-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in ./venv/lib/python3.10/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in ./venv/lib/python3.10/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in ./venv/lib/python3.10/site-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in ./venv/lib/python3.10/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in ./venv/lib/python3.10/site-packages (from torch) (12.8.90)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.10/site-packages (from python-dateutil>=2.8.0->qiskit) (1.16.0)
# Requirement already satisfied: pbr>=2.0.0 in ./venv/lib/python3.10/site-packages (from stevedore>=3.0.0->qiskit) (6.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./venv/lib/python3.10/site-packages (from sympy>=1.3->qiskit) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.10/site-packages (from jinja2->torch) (3.0.2)

# %%
# instalar as bibliotecas necessárias
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from qiskit import QuantumCircuit
from qiskit.circuit.library import ZZFeatureMap, RealAmplitudes
from qiskit.primitives import Sampler # Primitiva V2
from qiskit_machine_learning.neural_networks import SamplerQNN
from qiskit_machine_learning.connectors import TorchConnector
import torch
import torch.nn as nn
import numpy as np
import collections
from quantumnet.components import Network, Logger

# %% [markdown]
# # Controle de Aleatoriedade e Reprodutibilidade
# O trecho abaixo define uma semente fixa (SEED = 42) e a aplica nas bibliotecas random, numpy e torch. Isso garante que os resultados aleatórios (como inicialização de pesos e embaralhamento de dados) sejam os mesmos a cada execução do código, o que é essencial para fins de reprodutibilidade.
#
# Além disso, o uso de torch.use_deterministic_algorithms(True) força o PyTorch a utilizar apenas algoritmos determinísticos, evitando variações internas e tornando os experimentos mais consistentes e confiáveis.

# %%
SEED = 42
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

torch.use_deterministic_algorithms(True)

# %% [markdown]
# # Inicializar a rede

# %%
rede = Network()
rede.set_ready_topology('grade',8,3,3) 
rede.draw()
Logger.activate(Logger)
# Out:
# 2025-08-13 14:39:48,053: Host 0 inicializado com 0 qubits.
# 2025-08-13 14:39:48,055: Host 1 inicializado com 0 qubits.
# 2025-08-13 14:39:48,056: Host 2 inicializado com 0 qubits.
# 2025-08-13 14:39:48,056: Host 3 inicializado com 0 qubits.
# 2025-08-13 14:39:48,057: Host 4 inicializado com 0 qubits.
# 2025-08-13 14:39:48,058: Host 5 inicializado com 0 qubits.
# 2025-08-13 14:39:48,059: Host 6 inicializado com 0 qubits.
# 2025-08-13 14:39:48,059: Host 7 inicializado com 0 qubits.
# 2025-08-13 14:39:48,059: Host 8 inicializado com 0 qubits.
# 2025-08-13 14:39:48,060: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f88bfa30> adicionado ao canal.
# 2025-08-13 14:39:48,060: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80338bac0> adicionado ao canal.
# 2025-08-13 14:39:48,061: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff803244040> adicionado ao canal.
# 2025-08-13 14:39:48,062: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f90dbf40> adicionado ao canal.
# 2025-08-13 14:39:48,062: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8e87be0> adicionado ao canal.
# 2025-08-13 14:39:48,063: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f90dba60> adicionado ao canal.
# 2025-08-13 14:39:48,064: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8e87c40> adicionado ao canal.
# 2025-08-13 14:39:48,065: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f90db2b0> adicionado ao canal.
# 2025-08-13 14:39:48,067: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff803244130> adicionado ao canal.
# 2025-08-13 14:39:48,068: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f90dbee0> adicionado ao canal.
# 2025-08-13 14:39:48,069: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f90da470> adicionado ao canal.
# 2025-08-13 14:39:48,070: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9906110> adicionado ao canal.
# 2025-08-13 14:39:48,072: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f90dbac0> adicionado ao canal.
# 2025-08-13 14:39:48,074: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f90db2e0> adicionado ao canal.
# 2025-08-13 14:39:48,076: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9873490> adicionado ao canal.
# 2025-08-13 14:39:48,078: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9873f10> adicionado ao canal.
# 2025-08-13 14:39:48,079: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f90dab60> adicionado ao canal.
# 2025-08-13 14:39:48,079: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9873ca0> adicionado ao canal.
# 2025-08-13 14:39:48,080: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9873d90> adicionado ao canal.
# 2025-08-13 14:39:48,081: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9871270> adicionado ao canal.
# 2025-08-13 14:39:48,082: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80338bdf0> adicionado ao canal.
# 2025-08-13 14:39:48,082: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f98733a0> adicionado ao canal.
# 2025-08-13 14:39:48,083: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f98735b0> adicionado ao canal.
# 2025-08-13 14:39:48,084: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9872d10> adicionado ao canal.
# Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados

# %% [markdown]
# # Carrega o conjunto de dados Iris
# - X → dados (características/features)
# - y → rótulos (classes/labels)

# %%
iris = load_iris()
X = iris.data 
y = iris.target

# %% [markdown]
# # Divide os dados
# 80% treino e 20% teste
#
# - test_size -> define que 20% dos dados serão usados para teste (logo, 80% vão para treino)
# - random_state -> os dados são embaralhados aleatoriamente antes de dividir em treino e teste.
# - stratify -> mantém a mesma proporção de cada classe nos conjuntos de treino e teste (boa prática em classificações)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=SEED, stratify=y
)

print("Distribuição das classes no y_train e y_test:")
print("Treino:", collections.Counter(y_train))
print("Teste:", collections.Counter(y_test))
# Out:
# Distribuição das classes no y_train e y_test:
# Treino: Counter({np.int64(0): 40, np.int64(2): 40, np.int64(1): 40})
# Teste: Counter({np.int64(0): 10, np.int64(2): 10, np.int64(1): 10})

# %% [markdown]
# # Normaliza os dados
# - Normalizar = colocar tudo na mesma escala (de 0 a 1).
# - Isso ajuda o modelo a aprender melhor e evita que uma variável "grite" mais que as outras.
# - ex: Se uma variável vai de 0 a 1000 e outra vai de 0 a 1, a maior domina o aprendizado

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # Define número de qubits
# - Se o conjunto de dados tem 4 features (ex: comprimento da pétala, largura da pétala etc),
# - então são necessários 4 qubits para representar e processar cada uma dessas features no circuito quântico.

# %%
num_qubits = X_train.shape[1]

# %% [markdown]
# # Feature map e ansatz
# - Feature Map → insere as features no circuito quântico
# - RealAmplitudes → um tipo específico de ansatz do Qiskit, onde ele monta um circuito que trabalha com rotações e entrelaçamento. Isso faz com que ele consiga representar padrões/pesos diferentes nas features. "onde tem peso para aprender"
#
# - Quantos mais os números de reps crescer mais a chance de overfitting (treinar de uma forma errada)

# %%
feature_map = ZZFeatureMap(feature_dimension=num_qubits)
ansatz = RealAmplitudes(num_qubits, reps=2)

# %% [markdown]
# # Cria o circuito
# - etapa que cria um circuito quântico vazio, transforma os dados clássicos (números normais) em um estado quântico e ) e depois coloca o ansatz para o modelo conseguir aprender os padrões/pesos das features.

# %%
qc = QuantumCircuit(num_qubits)
qc.compose(feature_map, inplace=True)
qc.compose(ansatz, inplace=True)

# %% [markdown]
# # SamplerQNN
# - Ele usa o Sampler para fazer o trabalho quântico, mas adiciona toda a lógica necessaria para que o processo se pareça e se comporte como uma camada de uma rede neural.
#
# - E permite treinar ela usando PyTorch, igual uma rede neural clássica.

# %%
sampler = Sampler()
qnn = SamplerQNN(
    sampler=sampler, 
    circuit=qc,
    input_params=feature_map.parameters,  # Informa à QNN quais são os parâmetros de entrada
    weight_params=ansatz.parameters      # Informa à QNN quais são os pesos treináveis
)


model = nn.Sequential(
    TorchConnector(qnn),
    nn.Linear(qnn.output_shape[0], num_qubits)
)
# Out:
# /tmp/ipykernel_27252/504677551.py:1: DeprecationWarning: The class ``qiskit.primitives.sampler.Sampler`` is deprecated as of qiskit 1.2. It will be removed no earlier than 3 months after the release date. All implementations of the `BaseSamplerV1` interface have been deprecated in favor of their V2 counterparts. The V2 alternative for the `Sampler` class is `StatevectorSampler`.
#   sampler = Sampler()
# /tmp/ipykernel_27252/504677551.py:2: DeprecationWarning: V1 Primitives are deprecated as of qiskit-machine-learning 0.8.0 and will be removed no sooner than 4 months after the release date. Use V2 primitives for continued compatibility and support.
#   qnn = SamplerQNN(

# %% [markdown]
# # Otimização com PyTorch
# - X_train_tensor e y_train_tensor → Convertem os dados de treino (X_train e y_train) de NumPy pra tensor do PyTorch, que é o formato que o modelo entende.
#
# - optimizer = torch.optim.Adam(...) → Define o otimizador Adam, que ajusta os pesos do modelo pra minimizar o erro.
#
# - lr=0.1 → Taxa de aprendizado (velocidade que ele ajusta os pesos com base nos erros, não pode ser muito alto e não muito baixo).
#
# - loss_func = torch.nn.CrossEntropyLoss() → Esta é a função de perda padrão e mais recomendada para problemas de classificação multiclasse (quando você tem 3 ou mais classes possíveis, como no caso do dataset Iris).

# %%
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)

optimizer = torch.optim.Adam(model.parameters(), lr=0.1)
loss_func = torch.nn.CrossEntropyLoss()

# %% [markdown]
# # Treinamento
# - model.train() → Coloca o modelo no modo treino
# - optimizer.zero_grad() → Zera os gradientes dos cálculos anteriores pra não acumular.
# - outputs = model(X_train_tensor) →  usa os dados de treino no modelo para fazer uma previsão/estimativa.
# - loss → calcula o erro
# - loss.backward() → Calcula os gradientes, ou seja, descobre pra onde e quanto cada peso deve mudar pra reduzir o erro.
# - optimizer.step() → usa esses gradientes pra mudar os pesos do ansatz. Ele faz isso pra tentar diminuir o erro na próxima vez que roda

# %%
# --- 6. Loop de Treinamento com Simulação BQC ---
print("\nIniciando o treinamento...")
num_epochs = 10

for epoch in range(num_epochs):
    model.train()
    optimizer.zero_grad()
    
    outputs = model(X_train_tensor)
    
    loss = loss_func(outputs, y_train_tensor)
    loss.backward()
    optimizer.step()
    
    print(f"Época {epoch+1}/{num_epochs}, Perda (Loss): {loss.item():.4f}")

    # --- INÍCIO DA INTEGRAÇÃO DA REDE QUÂNTICA ---
    trained_weights = model[0].weight.detach().numpy()
    
    final_circuit = QuantumCircuit(num_qubits)
    final_circuit.compose(feature_map, inplace=True)
    final_circuit.compose(ansatz.assign_parameters(trained_weights), inplace=True)
    
    circuit_depth = final_circuit.depth()
    
    print(f"Executando simulação BQC para a época {epoch+1} com profundidade de circuito: {circuit_depth}")
    rede.application_layer.run_app(
        "AC_BQC",
        alice_id=6,
        bob_id=0,
        num_qubits=num_qubits,
        scenario=2,
        circuit_depth=circuit_depth
    )

    rede.start_eprs()
    # --- FIM DA INTEGRAÇÃO DA REDE QUÂNTICA ---
# Out:
# Iniciando o treinamento...
# 2025-08-13 14:40:25,510: Timeslot 0: Iniciando protocolo Andrew Childs entre Alice 6 e Bob 0.
# 2025-08-13 14:40:25,511: Limpando a memória do cliente (Alice) antes de iniciar o protocolo.
# 2025-08-13 14:40:25,511: Limpando a memória do servidor (Bob) antes de iniciar o protocolo.
# 2025-08-13 14:40:25,513: Cliente criou 4 qubits para a transmissão.
# 2025-08-13 14:40:25,513: Qubit 624 registrado no timeslot 0
# 2025-08-13 14:40:25,513: Qubit 792 registrado no timeslot 0
# 2025-08-13 14:40:25,514: Qubit 295 registrado no timeslot 0
# 2025-08-13 14:40:25,515: Qubit 941 registrado no timeslot 0
# 2025-08-13 14:40:25,515: Qubit 624 criado pelo Cliente - Estado: 0, Fase: 1
# 2025-08-13 14:40:25,515: Qubit 792 criado pelo Cliente - Estado: 0, Fase: 1
# 2025-08-13 14:40:25,516: Qubit 295 criado pelo Cliente - Estado: 0, Fase: 1
# 2025-08-13 14:40:25,516: Qubit 941 criado pelo Cliente - Estado: 0, Fase: 1
# 2025-08-13 14:40:25,517: Alice recebeu 4 qubits. Total: 4 qubits na memória.
# 2025-08-13 14:40:25,517: Instruções clássicas enviadas pelo Cliente: ['Y', 'X', 'Y', 'Z']
# 2025-08-13 14:40:25,518: Timeslot 1: Buscando rota válida entre 6 e 0.
# 2025-08-13 14:40:25,519: Rota válida encontrada: [6, 3, 0]
# 2025-08-13 14:40:25,520: Rota calculada para o transporte: [6, 3, 0]
# 2025-08-13 14:40:25,520: Timeslot 1: Limpando pares EPRs residuais antes de iniciar o protocolo.
# 2025-08-13 14:40:25,521: Pares EPRs limpos no segmento 6 -> 3.
# 2025-08-13 14:40:25,521: Pares EPRs limpos no segmento 3 -> 0.
# 2025-08-13 14:40:25,521: Usando a rota fornecida: [6, 3, 0]
# 2025-08-13 14:40:25,522: Ida: Criando 4 pares EPRs no segmento 6 -> 3.
# 2025-08-13 14:40:25,522: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9906110> adicionado ao canal (6, 3).
# 2025-08-13 14:40:25,522: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f90da4d0> adicionado ao canal (6, 3).
# 2025-08-13 14:40:25,522: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f88bfac0> adicionado ao canal (6, 3).
# 2025-08-13 14:40:25,523: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80323e320> adicionado ao canal (6, 3).
# 2025-08-13 14:40:25,523: Ida: Criando 4 pares EPRs no segmento 3 -> 0.
# 2025-08-13 14:40:25,524: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8c9b4c0> adicionado ao canal (3, 0).
# 2025-08-13 14:40:25,524: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80323e2f0> adicionado ao canal (3, 0).
# 2025-08-13 14:40:25,524: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80323f5e0> adicionado ao canal (3, 0).
# 2025-08-13 14:40:25,525: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80323fc10> adicionado ao canal (3, 0).
# 2025-08-13 14:40:25,525: Fidelidade do EPR 6->3: 1.0
# 2025-08-13 14:40:25,525: Fidelidade do EPR 3->0: 1.0
# 2025-08-13 14:40:25,526: Produto das fidelidades para rota [6, 3, 0]: 1.0
# 2025-08-13 14:40:25,526: Fidelidade atual da rota: 1.0
# 2025-08-13 14:40:25,526: Fidelidade final: 1.0000 (F_qubit: 0.9434 * F_rota: 1.0000)
# 2025-08-13 14:40:25,527: Fidelidade do EPR 6->3: 0.999
# 2025-08-13 14:40:25,527: Fidelidade do EPR 3->0: 0.999
# 2025-08-13 14:40:25,527: Produto das fidelidades para rota [6, 3, 0]: 0.998001
# 2025-08-13 14:40:25,528: Fidelidade atual da rota: 0.998001
# 2025-08-13 14:40:25,529: Fidelidade final: 0.9980 (F_qubit: 0.9699 * F_rota: 0.9980)
# 2025-08-13 14:40:25,530: Fidelidade do EPR 6->3: 0.998001
# 2025-08-13 14:40:25,531: Fidelidade do EPR 3->0: 0.998001
# 2025-08-13 14:40:25,532: Produto das fidelidades para rota [6, 3, 0]: 0.996005996001
# 2025-08-13 14:40:25,533: Fidelidade atual da rota: 0.996005996001
# 2025-08-13 14:40:25,533: Fidelidade final: 0.9960 (F_qubit: 0.9656 * F_rota: 0.9960)
# 2025-08-13 14:40:25,534: Fidelidade do EPR 6->3: 0.997002999
# 2025-08-13 14:40:25,534: Fidelidade do EPR 3->0: 0.997002999
# 2025-08-13 14:40:25,535: Produto das fidelidades para rota [6, 3, 0]: 0.994014980014994
# 2025-08-13 14:40:25,535: Fidelidade atual da rota: 0.994014980014994
# 2025-08-13 14:40:25,535: Fidelidade final: 0.9940 (F_qubit: 0.9692 * F_rota: 0.9940)
# 2025-08-13 14:40:25,536: Foram utilizados 8 pares EPRs ao longo da transmissão.
# 2025-08-13 14:40:25,536: Transmissão de 4 qubits entre 6 e 0 concluída com sucesso.
# 2025-08-13 14:40:25,537: Cliente enviou 4 qubits para o Servidor.
# 2025-08-13 14:40:25,537: Servidor tem 4 qubits na memória após a recepção.
# 2025-08-13 14:40:25,537: Timeslot 6: Servidor aplicando operações nos qubits.
# 2025-08-13 14:40:25,537: Timeslot 7: Servidor aplicando operações nos qubits.
# 2025-08-13 14:40:25,538: Servidor aplicou as operações instruídas pelo Cliente nos qubits.
# 2025-08-13 14:40:25,538: Qubit 624 após operações de Servidor - Estado: 1, Fase: -1
# 2025-08-13 14:40:25,538: Qubit 792 após operações de Servidor - Estado: 1, Fase: 1
# 2025-08-13 14:40:25,539: Qubit 295 após operações de Servidor - Estado: 1, Fase: -1
# 2025-08-13 14:40:25,539: Qubit 941 após operações de Servidor - Estado: 0, Fase: 1
# 2025-08-13 14:40:25,539: Limpando a memória do cliente antes de receber os qubits devolvidos.
# 2025-08-13 14:40:25,540: Usando a rota fornecida: [0, 3, 6]
# 2025-08-13 14:40:25,540: Volta: Criando 4 pares EPRs no segmento 0 -> 3.
# 2025-08-13 14:40:25,540: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9906110> adicionado ao canal (0, 3).
# 2025-08-13 14:40:25,540: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80323c0d0> adicionado ao canal (0, 3).
# 2025-08-13 14:40:25,541: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80323c280> adicionado ao canal (0, 3).
# 2025-08-13 14:40:25,541: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80323e7a0> adicionado ao canal (0, 3).
# 2025-08-13 14:40:25,541: Volta: Criando 4 pares EPRs no segmento 3 -> 6.
# 2025-08-13 14:40:25,542: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f88bfa30> adicionado ao canal (3, 6).
# 2025-08-13 14:40:25,542: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f90da470> adicionado ao canal (3, 6).
# 2025-08-13 14:40:25,542: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f88bfac0> adicionado ao canal (3, 6).
# 2025-08-13 14:40:25,543: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80323fc10> adicionado ao canal (3, 6).
# 2025-08-13 14:40:25,543: Fidelidade do EPR 0->3: 1.0
# 2025-08-13 14:40:25,543: Fidelidade do EPR 3->6: 1.0
# 2025-08-13 14:40:25,544: Produto das fidelidades para rota [0, 3, 6]: 1.0
# 2025-08-13 14:40:25,544: Fidelidade atual da rota: 1.0
# 2025-08-13 14:40:25,544: Fidelidade final: 1.0000 (F_qubit: 0.9378 * F_rota: 1.0000)
# 2025-08-13 14:40:25,545: Fidelidade do EPR 0->3: 0.999
# 2025-08-13 14:40:25,545: Fidelidade do EPR 3->6: 0.999
# 2025-08-13 14:40:25,546: Produto das fidelidades para rota [0, 3, 6]: 0.998001
# 2025-08-13 14:40:25,546: Fidelidade atual da rota: 0.998001
# 2025-08-13 14:40:25,547: Fidelidade final: 0.9980 (F_qubit: 0.9641 * F_rota: 0.9980)
# 2025-08-13 14:40:25,547: Fidelidade do EPR 0->3: 0.998001
# 2025-08-13 14:40:25,548: Fidelidade do EPR 3->6: 0.998001
# 2025-08-13 14:40:25,549: Produto das fidelidades para rota [0, 3, 6]: 0.996005996001
# 2025-08-13 14:40:25,550: Fidelidade atual da rota: 0.996005996001
# 2025-08-13 14:40:25,551: Fidelidade final: 0.9960 (F_qubit: 0.9598 * F_rota: 0.9960)
# 2025-08-13 14:40:25,551: Fidelidade do EPR 0->3: 0.997002999
# 2025-08-13 14:40:25,552: Fidelidade do EPR 3->6: 0.997002999
# 2025-08-13 14:40:25,552: Produto das fidelidades para rota [0, 3, 6]: 0.994014980014994
# 2025-08-13 14:40:25,552: Fidelidade atual da rota: 0.994014980014994
# 2025-08-13 14:40:25,552: Fidelidade final: 0.9940 (F_qubit: 0.9634 * F_rota: 0.9940)
# 2025-08-13 14:40:25,553: Foram utilizados 8 pares EPRs ao longo da transmissão.
# 2025-08-13 14:40:25,553: Transmissão de 4 qubits entre 0 e 6 concluída com sucesso.
# 2025-08-13 14:40:25,553: Servidor devolveu 0 qubits para o cliente.
# 2025-08-13 14:40:25,553: Qubit 624 devolvido para o cliente - Estado: 1, Fase: -1
# 2025-08-13 14:40:25,554: Qubit 792 devolvido para o cliente - Estado: 1, Fase: 1
# 2025-08-13 14:40:25,554: Qubit 295 devolvido para o cliente - Estado: 1, Fase: -1
# 2025-08-13 14:40:25,554: Qubit 941 devolvido para o cliente - Estado: 0, Fase: 1
# 2025-08-13 14:40:25,555: Cliente aplicou a decodificação Clifford no qubit 624.
# 2025-08-13 14:40:25,556: Cliente aplicou a decodificação Clifford no qubit 792.
# 2025-08-13 14:40:25,556: Cliente aplicou a decodificação Clifford no qubit 295.
# 2025-08-13 14:40:25,556: Cliente aplicou a decodificação Clifford no qubit 941.
# 2025-08-13 14:40:25,556: Protocolo concluído com sucesso. O cliente tem 4 qubits decodificados.
# 2025-08-13 14:40:25,557: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9906110> adicionado ao canal.
# 2025-08-13 14:40:25,557: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8c9add0> adicionado ao canal.
# 2025-08-13 14:40:25,557: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8940850> adicionado ao canal.
# 2025-08-13 14:40:25,557: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f90da470> adicionado ao canal.
# 2025-08-13 14:40:25,558: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8940730> adicionado ao canal.
# 2025-08-13 14:40:25,558: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8c9b4c0> adicionado ao canal.
# 2025-08-13 14:40:25,559: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9c2d2a0> adicionado ao canal.
# 2025-08-13 14:40:25,559: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8940700> adicionado ao canal.
# 2025-08-13 14:40:25,559: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8940820> adicionado ao canal.
# 2025-08-13 14:40:25,559: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f89405e0> adicionado ao canal.
# 2025-08-13 14:40:25,560: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8940910> adicionado ao canal.
# 2025-08-13 14:40:25,560: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80323c280> adicionado ao canal.
# 2025-08-13 14:40:25,561: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f88bfac0> adicionado ao canal.
# 2025-08-13 14:40:25,561: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80323e710> adicionado ao canal.
# 2025-08-13 14:40:25,561: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80323fb50> adicionado ao canal.
# 2025-08-13 14:40:25,563: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80323e470> adicionado ao canal.
# 2025-08-13 14:40:25,563: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80323eb90> adicionado ao canal.
# 2025-08-13 14:40:25,564: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80323fc10> adicionado ao canal.
# 2025-08-13 14:40:25,564: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80323ef20> adicionado ao canal.
# 2025-08-13 14:40:25,565: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80323c5e0> adicionado ao canal.
# 2025-08-13 14:40:25,565: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80323d3f0> adicionado ao canal.
# 2025-08-13 14:40:25,565: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80323f9d0> adicionado ao canal.
# 2025-08-13 14:40:25,566: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80323e320> adicionado ao canal.
# 2025-08-13 14:40:25,566: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80323d480> adicionado ao canal.
# Época 1/10, Perda (Loss): 1.4349
# Executando simulação BQC para a época 1 com profundidade de circuito: 2
# Tempo de Operação: 2
# Pares EPRs adicionados
# 2025-08-13 14:40:32,560: Timeslot 11: Iniciando protocolo Andrew Childs entre Alice 6 e Bob 0.
# 2025-08-13 14:40:32,561: Limpando a memória do cliente (Alice) antes de iniciar o protocolo.
# 2025-08-13 14:40:32,563: Limpando a memória do servidor (Bob) antes de iniciar o protocolo.
# 2025-08-13 14:40:32,564: Cliente criou 4 qubits para a transmissão.
# 2025-08-13 14:40:32,566: Qubit 367 registrado no timeslot 11
# 2025-08-13 14:40:32,567: Qubit 334 registrado no timeslot 11
# 2025-08-13 14:40:32,569: Qubit 919 registrado no timeslot 11
# 2025-08-13 14:40:32,570: Qubit 968 registrado no timeslot 11
# 2025-08-13 14:40:32,571: Qubit 367 criado pelo Cliente - Estado: 0, Fase: 1
# 2025-08-13 14:40:32,572: Qubit 334 criado pelo Cliente - Estado: 0, Fase: 1
# 2025-08-13 14:40:32,574: Qubit 919 criado pelo Cliente - Estado: 0, Fase: 1
# 2025-08-13 14:40:32,575: Qubit 968 criado pelo Cliente - Estado: 0, Fase: 1
# 2025-08-13 14:40:32,576: Alice recebeu 4 qubits. Total: 4 qubits na memória.
# 2025-08-13 14:40:32,578: Instruções clássicas enviadas pelo Cliente: ['Z', 'Y', 'X', 'X']
# 2025-08-13 14:40:32,580: Timeslot 12: Buscando rota válida entre 6 e 0.
# 2025-08-13 14:40:32,582: Rota válida encontrada: [6, 3, 0]
# 2025-08-13 14:40:32,584: Rota calculada para o transporte: [6, 3, 0]
# 2025-08-13 14:40:32,585: Timeslot 12: Limpando pares EPRs residuais antes de iniciar o protocolo.
# 2025-08-13 14:40:32,587: Pares EPRs limpos no segmento 6 -> 3.
# 2025-08-13 14:40:32,589: Pares EPRs limpos no segmento 3 -> 0.
# 2025-08-13 14:40:32,591: Usando a rota fornecida: [6, 3, 0]
# 2025-08-13 14:40:32,592: Ida: Criando 4 pares EPRs no segmento 6 -> 3.
# 2025-08-13 14:40:32,593: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f909f730> adicionado ao canal (6, 3).
# 2025-08-13 14:40:32,595: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9906110> adicionado ao canal (6, 3).
# 2025-08-13 14:40:32,596: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f88bfa30> adicionado ao canal (6, 3).
# 2025-08-13 14:40:32,597: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80323f760> adicionado ao canal (6, 3).
# 2025-08-13 14:40:32,604: Ida: Criando 4 pares EPRs no segmento 3 -> 0.
# 2025-08-13 14:40:32,606: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80323c280> adicionado ao canal (3, 0).
# 2025-08-13 14:40:32,608: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f88730d0> adicionado ao canal (3, 0).
# 2025-08-13 14:40:32,610: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8873520> adicionado ao canal (3, 0).
# 2025-08-13 14:40:32,612: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8940910> adicionado ao canal (3, 0).
# 2025-08-13 14:40:32,614: Fidelidade do EPR 6->3: 1.0
# 2025-08-13 14:40:32,616: Fidelidade do EPR 3->0: 1.0
# 2025-08-13 14:40:32,617: Produto das fidelidades para rota [6, 3, 0]: 1.0
# 2025-08-13 14:40:32,618: Fidelidade atual da rota: 1.0
# 2025-08-13 14:40:32,619: Fidelidade final: 1.0000 (F_qubit: 0.9567 * F_rota: 1.0000)
# 2025-08-13 14:40:32,620: Fidelidade do EPR 6->3: 0.999
# 2025-08-13 14:40:32,621: Fidelidade do EPR 3->0: 0.999
# 2025-08-13 14:40:32,621: Produto das fidelidades para rota [6, 3, 0]: 0.998001
# 2025-08-13 14:40:32,622: Fidelidade atual da rota: 0.998001
# 2025-08-13 14:40:32,622: Fidelidade final: 0.9980 (F_qubit: 0.9767 * F_rota: 0.9980)
# 2025-08-13 14:40:32,623: Fidelidade do EPR 6->3: 0.998001
# 2025-08-13 14:40:32,623: Fidelidade do EPR 3->0: 0.998001
# 2025-08-13 14:40:32,623: Produto das fidelidades para rota [6, 3, 0]: 0.996005996001
# 2025-08-13 14:40:32,624: Fidelidade atual da rota: 0.996005996001
# 2025-08-13 14:40:32,627: Fidelidade final: 0.9960 (F_qubit: 0.9483 * F_rota: 0.9960)
# 2025-08-13 14:40:32,628: Fidelidade do EPR 6->3: 0.997002999
# 2025-08-13 14:40:32,628: Fidelidade do EPR 3->0: 0.997002999
# 2025-08-13 14:40:32,629: Produto das fidelidades para rota [6, 3, 0]: 0.994014980014994
# 2025-08-13 14:40:32,629: Fidelidade atual da rota: 0.994014980014994
# 2025-08-13 14:40:32,630: Fidelidade final: 0.9940 (F_qubit: 0.9210 * F_rota: 0.9940)
# 2025-08-13 14:40:32,630: Foram utilizados 8 pares EPRs ao longo da transmissão.
# 2025-08-13 14:40:32,631: Transmissão de 4 qubits entre 6 e 0 concluída com sucesso.
# 2025-08-13 14:40:32,631: Cliente enviou 4 qubits para o Servidor.
# 2025-08-13 14:40:32,631: Servidor tem 4 qubits na memória após a recepção.
# 2025-08-13 14:40:32,632: Timeslot 17: Servidor aplicando operações nos qubits.
# 2025-08-13 14:40:32,632: Timeslot 18: Servidor aplicando operações nos qubits.
# 2025-08-13 14:40:32,633: Servidor aplicou as operações instruídas pelo Cliente nos qubits.
# 2025-08-13 14:40:32,633: Qubit 367 após operações de Servidor - Estado: 0, Fase: 1
# 2025-08-13 14:40:32,633: Qubit 334 após operações de Servidor - Estado: 1, Fase: -1
# 2025-08-13 14:40:32,633: Qubit 919 após operações de Servidor - Estado: 1, Fase: 1
# 2025-08-13 14:40:32,634: Qubit 968 após operações de Servidor - Estado: 1, Fase: 1
# 2025-08-13 14:40:32,634: Limpando a memória do cliente antes de receber os qubits devolvidos.
# 2025-08-13 14:40:32,635: Usando a rota fornecida: [0, 3, 6]
# 2025-08-13 14:40:32,635: Volta: Criando 4 pares EPRs no segmento 0 -> 3.
# 2025-08-13 14:40:32,636: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f88bfa30> adicionado ao canal (0, 3).
# 2025-08-13 14:40:32,637: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f909f730> adicionado ao canal (0, 3).
# 2025-08-13 14:40:32,640: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80323d930> adicionado ao canal (0, 3).
# 2025-08-13 14:40:32,640: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80323c280> adicionado ao canal (0, 3).
# 2025-08-13 14:40:32,641: Volta: Criando 4 pares EPRs no segmento 3 -> 6.
# 2025-08-13 14:40:32,641: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8940910> adicionado ao canal (3, 6).
# 2025-08-13 14:40:32,642: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f88730d0> adicionado ao canal (3, 6).
# 2025-08-13 14:40:32,642: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8872f80> adicionado ao canal (3, 6).
# 2025-08-13 14:40:32,642: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8873100> adicionado ao canal (3, 6).
# 2025-08-13 14:40:32,643: Fidelidade do EPR 0->3: 1.0
# 2025-08-13 14:40:32,643: Fidelidade do EPR 3->6: 1.0
# 2025-08-13 14:40:32,645: Produto das fidelidades para rota [0, 3, 6]: 1.0
# 2025-08-13 14:40:32,645: Fidelidade atual da rota: 1.0
# 2025-08-13 14:40:32,646: Fidelidade final: 1.0000 (F_qubit: 0.9510 * F_rota: 1.0000)
# 2025-08-13 14:40:32,646: Fidelidade do EPR 0->3: 0.999
# 2025-08-13 14:40:32,647: Fidelidade do EPR 3->6: 0.999
# 2025-08-13 14:40:32,647: Produto das fidelidades para rota [0, 3, 6]: 0.998001
# 2025-08-13 14:40:32,648: Fidelidade atual da rota: 0.998001
# 2025-08-13 14:40:32,648: Fidelidade final: 0.9980 (F_qubit: 0.9709 * F_rota: 0.9980)
# 2025-08-13 14:40:32,648: Fidelidade do EPR 0->3: 0.998001
# 2025-08-13 14:40:32,649: Fidelidade do EPR 3->6: 0.998001
# 2025-08-13 14:40:32,649: Produto das fidelidades para rota [0, 3, 6]: 0.996005996001
# 2025-08-13 14:40:32,650: Fidelidade atual da rota: 0.996005996001
# 2025-08-13 14:40:32,650: Fidelidade final: 0.9960 (F_qubit: 0.9426 * F_rota: 0.9960)
# 2025-08-13 14:40:32,650: Fidelidade do EPR 0->3: 0.997002999
# 2025-08-13 14:40:32,651: Fidelidade do EPR 3->6: 0.997002999
# 2025-08-13 14:40:32,652: Produto das fidelidades para rota [0, 3, 6]: 0.994014980014994
# 2025-08-13 14:40:32,652: Fidelidade atual da rota: 0.994014980014994
# 2025-08-13 14:40:32,652: Fidelidade final: 0.9940 (F_qubit: 0.9155 * F_rota: 0.9940)
# 2025-08-13 14:40:32,653: Foram utilizados 8 pares EPRs ao longo da transmissão.
# 2025-08-13 14:40:32,653: Transmissão de 4 qubits entre 0 e 6 concluída com sucesso.
# 2025-08-13 14:40:32,654: Servidor devolveu 0 qubits para o cliente.
# 2025-08-13 14:40:32,654: Qubit 367 devolvido para o cliente - Estado: 0, Fase: 1
# 2025-08-13 14:40:32,655: Qubit 334 devolvido para o cliente - Estado: 1, Fase: -1
# 2025-08-13 14:40:32,655: Qubit 919 devolvido para o cliente - Estado: 1, Fase: 1
# 2025-08-13 14:40:32,655: Qubit 968 devolvido para o cliente - Estado: 1, Fase: 1
# 2025-08-13 14:40:32,656: Cliente aplicou a decodificação Clifford no qubit 367.
# 2025-08-13 14:40:32,656: Cliente aplicou a decodificação Clifford no qubit 334.
# 2025-08-13 14:40:32,656: Cliente aplicou a decodificação Clifford no qubit 919.
# 2025-08-13 14:40:32,657: Cliente aplicou a decodificação Clifford no qubit 968.
# 2025-08-13 14:40:32,657: Protocolo concluído com sucesso. O cliente tem 4 qubits decodificados.
# 2025-08-13 14:40:32,657: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff8032a88e0> adicionado ao canal.
# 2025-08-13 14:40:32,658: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f909f730> adicionado ao canal.
# 2025-08-13 14:40:32,658: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f88bfa30> adicionado ao canal.
# 2025-08-13 14:40:32,659: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8ea4a90> adicionado ao canal.
# 2025-08-13 14:40:32,659: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9906110> adicionado ao canal.
# 2025-08-13 14:40:32,660: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80323f760> adicionado ao canal.
# 2025-08-13 14:40:32,663: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80323d4b0> adicionado ao canal.
# 2025-08-13 14:40:32,664: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8ea4970> adicionado ao canal.
# 2025-08-13 14:40:32,664: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80323f160> adicionado ao canal.
# 2025-08-13 14:40:32,665: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80323f250> adicionado ao canal.
# 2025-08-13 14:40:32,665: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8ea42b0> adicionado ao canal.
# 2025-08-13 14:40:32,665: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8873310> adicionado ao canal.
# 2025-08-13 14:40:32,666: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8ea42e0> adicionado ao canal.
# 2025-08-13 14:40:32,666: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f88730d0> adicionado ao canal.
# 2025-08-13 14:40:32,667: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8873520> adicionado ao canal.
# 2025-08-13 14:40:32,667: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f88734f0> adicionado ao canal.
# 2025-08-13 14:40:32,668: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8873370> adicionado ao canal.
# 2025-08-13 14:40:32,668: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8873220> adicionado ao canal.
# 2025-08-13 14:40:32,669: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8873280> adicionado ao canal.
# 2025-08-13 14:40:32,669: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8873700> adicionado ao canal.
# 2025-08-13 14:40:32,669: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f88730a0> adicionado ao canal.
# 2025-08-13 14:40:32,670: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8873790> adicionado ao canal.
# 2025-08-13 14:40:32,671: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8873730> adicionado ao canal.
# 2025-08-13 14:40:32,671: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8873850> adicionado ao canal.
# Época 2/10, Perda (Loss): 1.3299
# Executando simulação BQC para a época 2 com profundidade de circuito: 2
# Tempo de Operação: 2
# Pares EPRs adicionados
# 2025-08-13 14:40:39,776: Timeslot 22: Iniciando protocolo Andrew Childs entre Alice 6 e Bob 0.
# 2025-08-13 14:40:39,777: Limpando a memória do cliente (Alice) antes de iniciar o protocolo.
# 2025-08-13 14:40:39,778: Limpando a memória do servidor (Bob) antes de iniciar o protocolo.
# 2025-08-13 14:40:39,779: Cliente criou 4 qubits para a transmissão.
# 2025-08-13 14:40:39,780: Qubit 264 registrado no timeslot 22
# 2025-08-13 14:40:39,780: Qubit 308 registrado no timeslot 22
# 2025-08-13 14:40:39,780: Qubit 561 registrado no timeslot 22
# 2025-08-13 14:40:39,781: Qubit 489 registrado no timeslot 22
# 2025-08-13 14:40:39,781: Qubit 264 criado pelo Cliente - Estado: 0, Fase: 1
# 2025-08-13 14:40:39,783: Qubit 308 criado pelo Cliente - Estado: 0, Fase: 1
# 2025-08-13 14:40:39,783: Qubit 561 criado pelo Cliente - Estado: 0, Fase: 1
# 2025-08-13 14:40:39,784: Qubit 489 criado pelo Cliente - Estado: 0, Fase: 1
# 2025-08-13 14:40:39,784: Alice recebeu 4 qubits. Total: 4 qubits na memória.
# 2025-08-13 14:40:39,785: Instruções clássicas enviadas pelo Cliente: ['Z', 'X', 'Z', 'Y']
# 2025-08-13 14:40:39,785: Timeslot 23: Buscando rota válida entre 6 e 0.
# 2025-08-13 14:40:39,786: Rota válida encontrada: [6, 3, 0]
# 2025-08-13 14:40:39,786: Rota calculada para o transporte: [6, 3, 0]
# 2025-08-13 14:40:39,787: Timeslot 23: Limpando pares EPRs residuais antes de iniciar o protocolo.
# 2025-08-13 14:40:39,787: Pares EPRs limpos no segmento 6 -> 3.
# 2025-08-13 14:40:39,787: Pares EPRs limpos no segmento 3 -> 0.
# 2025-08-13 14:40:39,788: Usando a rota fornecida: [6, 3, 0]
# 2025-08-13 14:40:39,788: Ida: Criando 4 pares EPRs no segmento 6 -> 3.
# 2025-08-13 14:40:39,789: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff8032a88e0> adicionado ao canal (6, 3).
# 2025-08-13 14:40:39,789: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8909e40> adicionado ao canal (6, 3).
# 2025-08-13 14:40:39,789: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f89094e0> adicionado ao canal (6, 3).
# 2025-08-13 14:40:39,790: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f89095d0> adicionado ao canal (6, 3).
# 2025-08-13 14:40:39,790: Ida: Criando 4 pares EPRs no segmento 3 -> 0.
# 2025-08-13 14:40:39,791: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8909510> adicionado ao canal (3, 0).
# 2025-08-13 14:40:39,791: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f89096f0> adicionado ao canal (3, 0).
# 2025-08-13 14:40:39,793: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8909b10> adicionado ao canal (3, 0).
# 2025-08-13 14:40:39,794: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8909bd0> adicionado ao canal (3, 0).
# 2025-08-13 14:40:39,794: Fidelidade do EPR 6->3: 1.0
# 2025-08-13 14:40:39,794: Fidelidade do EPR 3->0: 1.0
# 2025-08-13 14:40:39,795: Produto das fidelidades para rota [6, 3, 0]: 1.0
# 2025-08-13 14:40:39,795: Fidelidade atual da rota: 1.0
# 2025-08-13 14:40:39,796: Fidelidade final: 1.0000 (F_qubit: 0.9264 * F_rota: 1.0000)
# 2025-08-13 14:40:39,796: Fidelidade do EPR 6->3: 0.999
# 2025-08-13 14:40:39,797: Fidelidade do EPR 3->0: 0.999
# 2025-08-13 14:40:39,797: Produto das fidelidades para rota [6, 3, 0]: 0.998001
# 2025-08-13 14:40:39,797: Fidelidade atual da rota: 0.998001
# 2025-08-13 14:40:39,798: Fidelidade final: 0.9980 (F_qubit: 0.9742 * F_rota: 0.9980)
# 2025-08-13 14:40:39,799: Fidelidade do EPR 6->3: 0.998001
# 2025-08-13 14:40:39,801: Fidelidade do EPR 3->0: 0.998001
# 2025-08-13 14:40:39,801: Produto das fidelidades para rota [6, 3, 0]: 0.996005996001
# 2025-08-13 14:40:39,802: Fidelidade atual da rota: 0.996005996001
# 2025-08-13 14:40:39,802: Fidelidade final: 0.9960 (F_qubit: 0.9084 * F_rota: 0.9960)
# 2025-08-13 14:40:39,803: Fidelidade do EPR 6->3: 0.997002999
# 2025-08-13 14:40:39,804: Fidelidade do EPR 3->0: 0.997002999
# 2025-08-13 14:40:39,804: Produto das fidelidades para rota [6, 3, 0]: 0.994014980014994
# 2025-08-13 14:40:39,805: Fidelidade atual da rota: 0.994014980014994
# 2025-08-13 14:40:39,805: Fidelidade final: 0.9940 (F_qubit: 0.9817 * F_rota: 0.9940)
# 2025-08-13 14:40:39,806: Foram utilizados 8 pares EPRs ao longo da transmissão.
# 2025-08-13 14:40:39,806: Transmissão de 4 qubits entre 6 e 0 concluída com sucesso.
# 2025-08-13 14:40:39,807: Cliente enviou 4 qubits para o Servidor.
# 2025-08-13 14:40:39,807: Servidor tem 4 qubits na memória após a recepção.
# 2025-08-13 14:40:39,808: Timeslot 28: Servidor aplicando operações nos qubits.
# 2025-08-13 14:40:39,808: Timeslot 29: Servidor aplicando operações nos qubits.
# 2025-08-13 14:40:39,809: Servidor aplicou as operações instruídas pelo Cliente nos qubits.
# 2025-08-13 14:40:39,809: Qubit 264 após operações de Servidor - Estado: 0, Fase: 1
# 2025-08-13 14:40:39,809: Qubit 308 após operações de Servidor - Estado: 1, Fase: 1
# 2025-08-13 14:40:39,810: Qubit 561 após operações de Servidor - Estado: 0, Fase: 1
# 2025-08-13 14:40:39,810: Qubit 489 após operações de Servidor - Estado: 1, Fase: -1
# 2025-08-13 14:40:39,810: Limpando a memória do cliente antes de receber os qubits devolvidos.
# 2025-08-13 14:40:39,811: Usando a rota fornecida: [0, 3, 6]
# 2025-08-13 14:40:39,811: Volta: Criando 4 pares EPRs no segmento 0 -> 3.
# 2025-08-13 14:40:39,811: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff8032a88e0> adicionado ao canal (0, 3).
# 2025-08-13 14:40:39,814: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8909f90> adicionado ao canal (0, 3).
# 2025-08-13 14:40:39,815: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f89097b0> adicionado ao canal (0, 3).
# 2025-08-13 14:40:39,815: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f89094e0> adicionado ao canal (0, 3).
# 2025-08-13 14:40:39,815: Volta: Criando 4 pares EPRs no segmento 3 -> 6.
# 2025-08-13 14:40:39,816: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f89094b0> adicionado ao canal (3, 6).
# 2025-08-13 14:40:39,816: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8909480> adicionado ao canal (3, 6).
# 2025-08-13 14:40:39,817: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8909b40> adicionado ao canal (3, 6).
# 2025-08-13 14:40:39,818: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8909cf0> adicionado ao canal (3, 6).
# 2025-08-13 14:40:39,818: Fidelidade do EPR 0->3: 1.0
# 2025-08-13 14:40:39,819: Fidelidade do EPR 3->6: 1.0
# 2025-08-13 14:40:39,819: Produto das fidelidades para rota [0, 3, 6]: 1.0
# 2025-08-13 14:40:39,819: Fidelidade atual da rota: 1.0
# 2025-08-13 14:40:39,820: Fidelidade final: 1.0000 (F_qubit: 0.9209 * F_rota: 1.0000)
# 2025-08-13 14:40:39,821: Fidelidade do EPR 0->3: 0.999
# 2025-08-13 14:40:39,821: Fidelidade do EPR 3->6: 0.999
# 2025-08-13 14:40:39,821: Produto das fidelidades para rota [0, 3, 6]: 0.998001
# 2025-08-13 14:40:39,822: Fidelidade atual da rota: 0.998001
# 2025-08-13 14:40:39,822: Fidelidade final: 0.9980 (F_qubit: 0.9684 * F_rota: 0.9980)
# 2025-08-13 14:40:39,823: Fidelidade do EPR 0->3: 0.998001
# 2025-08-13 14:40:39,823: Fidelidade do EPR 3->6: 0.998001
# 2025-08-13 14:40:39,824: Produto das fidelidades para rota [0, 3, 6]: 0.996005996001
# 2025-08-13 14:40:39,824: Fidelidade atual da rota: 0.996005996001
# 2025-08-13 14:40:39,825: Fidelidade final: 0.9960 (F_qubit: 0.9030 * F_rota: 0.9960)
# 2025-08-13 14:40:39,825: Fidelidade do EPR 0->3: 0.997002999
# 2025-08-13 14:40:39,828: Fidelidade do EPR 3->6: 0.997002999
# 2025-08-13 14:40:39,829: Produto das fidelidades para rota [0, 3, 6]: 0.994014980014994
# 2025-08-13 14:40:39,829: Fidelidade atual da rota: 0.994014980014994
# 2025-08-13 14:40:39,830: Fidelidade final: 0.9940 (F_qubit: 0.9758 * F_rota: 0.9940)
# 2025-08-13 14:40:39,830: Foram utilizados 8 pares EPRs ao longo da transmissão.
# 2025-08-13 14:40:39,831: Transmissão de 4 qubits entre 0 e 6 concluída com sucesso.
# 2025-08-13 14:40:39,831: Servidor devolveu 0 qubits para o cliente.
# 2025-08-13 14:40:39,832: Qubit 264 devolvido para o cliente - Estado: 0, Fase: 1
# 2025-08-13 14:40:39,832: Qubit 308 devolvido para o cliente - Estado: 1, Fase: 1
# 2025-08-13 14:40:39,832: Qubit 561 devolvido para o cliente - Estado: 0, Fase: 1
# 2025-08-13 14:40:39,833: Qubit 489 devolvido para o cliente - Estado: 1, Fase: -1
# 2025-08-13 14:40:39,833: Cliente aplicou a decodificação Clifford no qubit 264.
# 2025-08-13 14:40:39,834: Cliente aplicou a decodificação Clifford no qubit 308.
# 2025-08-13 14:40:39,834: Cliente aplicou a decodificação Clifford no qubit 561.
# 2025-08-13 14:40:39,834: Cliente aplicou a decodificação Clifford no qubit 489.
# 2025-08-13 14:40:39,835: Protocolo concluído com sucesso. O cliente tem 4 qubits decodificados.
# 2025-08-13 14:40:39,835: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff8032a88e0> adicionado ao canal.
# 2025-08-13 14:40:39,836: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9307cd0> adicionado ao canal.
# 2025-08-13 14:40:39,836: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff8119becb0> adicionado ao canal.
# 2025-08-13 14:40:39,837: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80311a9e0> adicionado ao canal.
# 2025-08-13 14:40:39,837: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff803119e70> adicionado ao canal.
# 2025-08-13 14:40:39,838: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80311aad0> adicionado ao canal.
# 2025-08-13 14:40:39,838: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80311a7a0> adicionado ao canal.
# 2025-08-13 14:40:39,842: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f89097b0> adicionado ao canal.
# 2025-08-13 14:40:39,842: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80311a4d0> adicionado ao canal.
# 2025-08-13 14:40:39,843: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8909f90> adicionado ao canal.
# 2025-08-13 14:40:39,843: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8909ff0> adicionado ao canal.
# 2025-08-13 14:40:39,844: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8909660> adicionado ao canal.
# 2025-08-13 14:40:39,844: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8909de0> adicionado ao canal.
# 2025-08-13 14:40:39,844: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f890bee0> adicionado ao canal.
# 2025-08-13 14:40:39,845: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8909c00> adicionado ao canal.
# 2025-08-13 14:40:39,845: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8909870> adicionado ao canal.
# 2025-08-13 14:40:39,845: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f890a3b0> adicionado ao canal.
# 2025-08-13 14:40:39,847: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8909bd0> adicionado ao canal.
# 2025-08-13 14:40:39,847: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8909a50> adicionado ao canal.
# 2025-08-13 14:40:39,848: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f89095d0> adicionado ao canal.
# 2025-08-13 14:40:39,848: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8909810> adicionado ao canal.
# 2025-08-13 14:40:39,848: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8909b70> adicionado ao canal.
# 2025-08-13 14:40:39,849: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8909900> adicionado ao canal.
# 2025-08-13 14:40:39,849: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8908fa0> adicionado ao canal.
# Época 3/10, Perda (Loss): 1.2507
# Executando simulação BQC para a época 3 com profundidade de circuito: 2
# Tempo de Operação: 2
# Pares EPRs adicionados
# 2025-08-13 14:40:46,798: Timeslot 33: Iniciando protocolo Andrew Childs entre Alice 6 e Bob 0.
# 2025-08-13 14:40:46,799: Limpando a memória do cliente (Alice) antes de iniciar o protocolo.
# 2025-08-13 14:40:46,800: Limpando a memória do servidor (Bob) antes de iniciar o protocolo.
# 2025-08-13 14:40:46,801: Cliente criou 4 qubits para a transmissão.
# 2025-08-13 14:40:46,802: Qubit 982 registrado no timeslot 33
# 2025-08-13 14:40:46,802: Qubit 499 registrado no timeslot 33
# 2025-08-13 14:40:46,803: Qubit 259 registrado no timeslot 33
# 2025-08-13 14:40:46,803: Qubit 105 registrado no timeslot 33
# 2025-08-13 14:40:46,804: Qubit 982 criado pelo Cliente - Estado: 0, Fase: 1
# 2025-08-13 14:40:46,804: Qubit 499 criado pelo Cliente - Estado: 0, Fase: 1
# 2025-08-13 14:40:46,804: Qubit 259 criado pelo Cliente - Estado: 0, Fase: 1
# 2025-08-13 14:40:46,805: Qubit 105 criado pelo Cliente - Estado: 0, Fase: 1
# 2025-08-13 14:40:46,805: Alice recebeu 4 qubits. Total: 4 qubits na memória.
# 2025-08-13 14:40:46,805: Instruções clássicas enviadas pelo Cliente: ['X', 'Y', 'Z', 'Y']
# 2025-08-13 14:40:46,806: Timeslot 34: Buscando rota válida entre 6 e 0.
# 2025-08-13 14:40:46,808: Rota válida encontrada: [6, 3, 0]
# 2025-08-13 14:40:46,808: Rota calculada para o transporte: [6, 3, 0]
# 2025-08-13 14:40:46,809: Timeslot 34: Limpando pares EPRs residuais antes de iniciar o protocolo.
# 2025-08-13 14:40:46,809: Pares EPRs limpos no segmento 6 -> 3.
# 2025-08-13 14:40:46,810: Pares EPRs limpos no segmento 3 -> 0.
# 2025-08-13 14:40:46,810: Usando a rota fornecida: [6, 3, 0]
# 2025-08-13 14:40:46,811: Ida: Criando 4 pares EPRs no segmento 6 -> 3.
# 2025-08-13 14:40:46,811: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff8032a88e0> adicionado ao canal (6, 3).
# 2025-08-13 14:40:46,812: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9305b10> adicionado ao canal (6, 3).
# 2025-08-13 14:40:46,812: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8909f60> adicionado ao canal (6, 3).
# 2025-08-13 14:40:46,813: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9226f20> adicionado ao canal (6, 3).
# 2025-08-13 14:40:46,813: Ida: Criando 4 pares EPRs no segmento 3 -> 0.
# 2025-08-13 14:40:46,816: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8909660> adicionado ao canal (3, 0).
# 2025-08-13 14:40:46,817: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f89099c0> adicionado ao canal (3, 0).
# 2025-08-13 14:40:46,817: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9226c80> adicionado ao canal (3, 0).
# 2025-08-13 14:40:46,818: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9226fb0> adicionado ao canal (3, 0).
# 2025-08-13 14:40:46,818: Fidelidade do EPR 6->3: 1.0
# 2025-08-13 14:40:46,818: Fidelidade do EPR 3->0: 1.0
# 2025-08-13 14:40:46,819: Produto das fidelidades para rota [6, 3, 0]: 1.0
# 2025-08-13 14:40:46,819: Fidelidade atual da rota: 1.0
# 2025-08-13 14:40:46,819: Fidelidade final: 1.0000 (F_qubit: 0.9208 * F_rota: 1.0000)
# 2025-08-13 14:40:46,820: Fidelidade do EPR 6->3: 0.999
# 2025-08-13 14:40:46,820: Fidelidade do EPR 3->0: 0.999
# 2025-08-13 14:40:46,821: Produto das fidelidades para rota [6, 3, 0]: 0.998001
# 2025-08-13 14:40:46,822: Fidelidade atual da rota: 0.998001
# 2025-08-13 14:40:46,823: Fidelidade final: 0.9980 (F_qubit: 0.9683 * F_rota: 0.9980)
# 2025-08-13 14:40:46,824: Fidelidade do EPR 6->3: 0.998001
# 2025-08-13 14:40:46,826: Fidelidade do EPR 3->0: 0.998001
# 2025-08-13 14:40:46,827: Produto das fidelidades para rota [6, 3, 0]: 0.996005996001
# 2025-08-13 14:40:46,827: Fidelidade atual da rota: 0.996005996001
# 2025-08-13 14:40:46,828: Fidelidade final: 0.9960 (F_qubit: 0.9155 * F_rota: 0.9960)
# 2025-08-13 14:40:46,829: Fidelidade do EPR 6->3: 0.997002999
# 2025-08-13 14:40:46,830: Fidelidade do EPR 3->0: 0.997002999
# 2025-08-13 14:40:46,830: Produto das fidelidades para rota [6, 3, 0]: 0.994014980014994
# 2025-08-13 14:40:46,831: Fidelidade atual da rota: 0.994014980014994
# 2025-08-13 14:40:46,832: Fidelidade final: 0.9940 (F_qubit: 0.9267 * F_rota: 0.9940)
# 2025-08-13 14:40:46,832: Foram utilizados 8 pares EPRs ao longo da transmissão.
# 2025-08-13 14:40:46,833: Transmissão de 4 qubits entre 6 e 0 concluída com sucesso.
# 2025-08-13 14:40:46,833: Cliente enviou 4 qubits para o Servidor.
# 2025-08-13 14:40:46,834: Servidor tem 4 qubits na memória após a recepção.
# 2025-08-13 14:40:46,834: Timeslot 39: Servidor aplicando operações nos qubits.
# 2025-08-13 14:40:46,835: Timeslot 40: Servidor aplicando operações nos qubits.
# 2025-08-13 14:40:46,835: Servidor aplicou as operações instruídas pelo Cliente nos qubits.
# 2025-08-13 14:40:46,836: Qubit 982 após operações de Servidor - Estado: 1, Fase: 1
# 2025-08-13 14:40:46,836: Qubit 499 após operações de Servidor - Estado: 1, Fase: -1
# 2025-08-13 14:40:46,837: Qubit 259 após operações de Servidor - Estado: 0, Fase: 1
# 2025-08-13 14:40:46,843: Qubit 105 após operações de Servidor - Estado: 1, Fase: -1
# 2025-08-13 14:40:46,844: Limpando a memória do cliente antes de receber os qubits devolvidos.
# 2025-08-13 14:40:46,846: Usando a rota fornecida: [0, 3, 6]
# 2025-08-13 14:40:46,848: Volta: Criando 4 pares EPRs no segmento 0 -> 3.
# 2025-08-13 14:40:46,850: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9634070> adicionado ao canal (0, 3).
# 2025-08-13 14:40:46,853: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f89099f0> adicionado ao canal (0, 3).
# 2025-08-13 14:40:46,855: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8909f60> adicionado ao canal (0, 3).
# 2025-08-13 14:40:46,856: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9226a70> adicionado ao canal (0, 3).
# 2025-08-13 14:40:46,858: Volta: Criando 4 pares EPRs no segmento 3 -> 6.
# 2025-08-13 14:40:46,860: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8909ed0> adicionado ao canal (3, 6).
# 2025-08-13 14:40:46,861: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9226ec0> adicionado ao canal (3, 6).
# 2025-08-13 14:40:46,863: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9226f80> adicionado ao canal (3, 6).
# 2025-08-13 14:40:46,865: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9226b90> adicionado ao canal (3, 6).
# 2025-08-13 14:40:46,867: Fidelidade do EPR 0->3: 1.0
# 2025-08-13 14:40:46,868: Fidelidade do EPR 3->6: 1.0
# 2025-08-13 14:40:46,870: Produto das fidelidades para rota [0, 3, 6]: 1.0
# 2025-08-13 14:40:46,871: Fidelidade atual da rota: 1.0
# 2025-08-13 14:40:46,873: Fidelidade final: 1.0000 (F_qubit: 0.9153 * F_rota: 1.0000)
# 2025-08-13 14:40:46,876: Fidelidade do EPR 0->3: 0.999
# 2025-08-13 14:40:46,877: Fidelidade do EPR 3->6: 0.999
# 2025-08-13 14:40:46,879: Produto das fidelidades para rota [0, 3, 6]: 0.998001
# 2025-08-13 14:40:46,880: Fidelidade atual da rota: 0.998001
# 2025-08-13 14:40:46,881: Fidelidade final: 0.9980 (F_qubit: 0.9625 * F_rota: 0.9980)
# 2025-08-13 14:40:46,883: Fidelidade do EPR 0->3: 0.998001
# 2025-08-13 14:40:46,884: Fidelidade do EPR 3->6: 0.998001
# 2025-08-13 14:40:46,885: Produto das fidelidades para rota [0, 3, 6]: 0.996005996001
# 2025-08-13 14:40:46,886: Fidelidade atual da rota: 0.996005996001
# 2025-08-13 14:40:46,887: Fidelidade final: 0.9960 (F_qubit: 0.9100 * F_rota: 0.9960)
# 2025-08-13 14:40:46,888: Fidelidade do EPR 0->3: 0.997002999
# 2025-08-13 14:40:46,890: Fidelidade do EPR 3->6: 0.997002999
# 2025-08-13 14:40:46,893: Produto das fidelidades para rota [0, 3, 6]: 0.994014980014994
# 2025-08-13 14:40:46,895: Fidelidade atual da rota: 0.994014980014994
# 2025-08-13 14:40:46,897: Fidelidade final: 0.9940 (F_qubit: 0.9212 * F_rota: 0.9940)
# 2025-08-13 14:40:46,898: Foram utilizados 8 pares EPRs ao longo da transmissão.
# 2025-08-13 14:40:46,899: Transmissão de 4 qubits entre 0 e 6 concluída com sucesso.
# 2025-08-13 14:40:46,900: Servidor devolveu 0 qubits para o cliente.
# 2025-08-13 14:40:46,903: Qubit 982 devolvido para o cliente - Estado: 1, Fase: 1
# 2025-08-13 14:40:46,904: Qubit 499 devolvido para o cliente - Estado: 1, Fase: -1
# 2025-08-13 14:40:46,905: Qubit 259 devolvido para o cliente - Estado: 0, Fase: 1
# 2025-08-13 14:40:46,906: Qubit 105 devolvido para o cliente - Estado: 1, Fase: -1
# 2025-08-13 14:40:46,906: Cliente aplicou a decodificação Clifford no qubit 982.
# 2025-08-13 14:40:46,907: Cliente aplicou a decodificação Clifford no qubit 499.
# 2025-08-13 14:40:46,908: Cliente aplicou a decodificação Clifford no qubit 259.
# 2025-08-13 14:40:46,913: Cliente aplicou a decodificação Clifford no qubit 105.
# 2025-08-13 14:40:46,914: Protocolo concluído com sucesso. O cliente tem 4 qubits decodificados.
# 2025-08-13 14:40:46,918: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9634070> adicionado ao canal.
# 2025-08-13 14:40:46,919: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8909c60> adicionado ao canal.
# 2025-08-13 14:40:46,920: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff8031182e0> adicionado ao canal.
# 2025-08-13 14:40:46,921: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff803118ac0> adicionado ao canal.
# 2025-08-13 14:40:46,922: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff8031184f0> adicionado ao canal.
# 2025-08-13 14:40:46,923: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9226ce0> adicionado ao canal.
# 2025-08-13 14:40:46,925: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f92dd720> adicionado ao canal.
# 2025-08-13 14:40:46,925: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f89099c0> adicionado ao canal.
# 2025-08-13 14:40:46,926: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff803119000> adicionado ao canal.
# 2025-08-13 14:40:46,927: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f92270d0> adicionado ao canal.
# 2025-08-13 14:40:46,929: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff803119b70> adicionado ao canal.
# 2025-08-13 14:40:46,930: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80311b790> adicionado ao canal.
# 2025-08-13 14:40:46,930: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff8119e9ff0> adicionado ao canal.
# 2025-08-13 14:40:46,930: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9226e90> adicionado ao canal.
# 2025-08-13 14:40:46,931: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff8031184c0> adicionado ao canal.
# 2025-08-13 14:40:46,932: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9226c50> adicionado ao canal.
# 2025-08-13 14:40:46,932: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9226bf0> adicionado ao canal.
# 2025-08-13 14:40:46,933: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9226a70> adicionado ao canal.
# 2025-08-13 14:40:46,933: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9227100> adicionado ao canal.
# 2025-08-13 14:40:46,934: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9226b00> adicionado ao canal.
# 2025-08-13 14:40:46,934: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9226bc0> adicionado ao canal.
# 2025-08-13 14:40:46,935: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9226aa0> adicionado ao canal.
# 2025-08-13 14:40:46,935: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9226e60> adicionado ao canal.
# 2025-08-13 14:40:46,937: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f92272e0> adicionado ao canal.
# Época 4/10, Perda (Loss): 1.1910
# Executando simulação BQC para a época 4 com profundidade de circuito: 2
# Tempo de Operação: 2
# Pares EPRs adicionados
# 2025-08-13 14:40:53,803: Timeslot 44: Iniciando protocolo Andrew Childs entre Alice 6 e Bob 0.
# 2025-08-13 14:40:53,804: Limpando a memória do cliente (Alice) antes de iniciar o protocolo.
# 2025-08-13 14:40:53,805: Limpando a memória do servidor (Bob) antes de iniciar o protocolo.
# 2025-08-13 14:40:53,806: Cliente criou 4 qubits para a transmissão.
# 2025-08-13 14:40:53,806: Qubit 179 registrado no timeslot 44
# 2025-08-13 14:40:53,807: Qubit 753 registrado no timeslot 44
# 2025-08-13 14:40:53,808: Qubit 815 registrado no timeslot 44
# 2025-08-13 14:40:53,808: Qubit 491 registrado no timeslot 44
# 2025-08-13 14:40:53,809: Qubit 179 criado pelo Cliente - Estado: 0, Fase: 1
# 2025-08-13 14:40:53,809: Qubit 753 criado pelo Cliente - Estado: 0, Fase: 1
# 2025-08-13 14:40:53,810: Qubit 815 criado pelo Cliente - Estado: 0, Fase: 1
# 2025-08-13 14:40:53,810: Qubit 491 criado pelo Cliente - Estado: 0, Fase: 1
# 2025-08-13 14:40:53,810: Alice recebeu 4 qubits. Total: 4 qubits na memória.
# 2025-08-13 14:40:53,811: Instruções clássicas enviadas pelo Cliente: ['Y', 'Y', 'X', 'X']
# 2025-08-13 14:40:53,811: Timeslot 45: Buscando rota válida entre 6 e 0.
# 2025-08-13 14:40:53,812: Rota válida encontrada: [6, 3, 0]
# 2025-08-13 14:40:53,812: Rota calculada para o transporte: [6, 3, 0]
# 2025-08-13 14:40:53,815: Timeslot 45: Limpando pares EPRs residuais antes de iniciar o protocolo.
# 2025-08-13 14:40:53,815: Pares EPRs limpos no segmento 6 -> 3.
# 2025-08-13 14:40:53,816: Pares EPRs limpos no segmento 3 -> 0.
# 2025-08-13 14:40:53,816: Usando a rota fornecida: [6, 3, 0]
# 2025-08-13 14:40:53,816: Ida: Criando 4 pares EPRs no segmento 6 -> 3.
# 2025-08-13 14:40:53,817: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9307cd0> adicionado ao canal (6, 3).
# 2025-08-13 14:40:53,817: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7fa6bc2e0> adicionado ao canal (6, 3).
# 2025-08-13 14:40:53,817: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7fa6bc8b0> adicionado ao canal (6, 3).
# 2025-08-13 14:40:53,817: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff803119b70> adicionado ao canal (6, 3).
# 2025-08-13 14:40:53,818: Ida: Criando 4 pares EPRs no segmento 3 -> 0.
# 2025-08-13 14:40:53,818: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9226da0> adicionado ao canal (3, 0).
# 2025-08-13 14:40:53,818: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9226dd0> adicionado ao canal (3, 0).
# 2025-08-13 14:40:53,818: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7fa6bc970> adicionado ao canal (3, 0).
# 2025-08-13 14:40:53,819: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7fa6bca30> adicionado ao canal (3, 0).
# 2025-08-13 14:40:53,820: Fidelidade do EPR 6->3: 1.0
# 2025-08-13 14:40:53,820: Fidelidade do EPR 3->0: 1.0
# 2025-08-13 14:40:53,821: Produto das fidelidades para rota [6, 3, 0]: 1.0
# 2025-08-13 14:40:53,821: Fidelidade atual da rota: 1.0
# 2025-08-13 14:40:53,822: Fidelidade final: 1.0000 (F_qubit: 0.9424 * F_rota: 1.0000)
# 2025-08-13 14:40:53,823: Fidelidade do EPR 6->3: 0.999
# 2025-08-13 14:40:53,823: Fidelidade do EPR 3->0: 0.999
# 2025-08-13 14:40:53,824: Produto das fidelidades para rota [6, 3, 0]: 0.998001
# 2025-08-13 14:40:53,825: Fidelidade atual da rota: 0.998001
# 2025-08-13 14:40:53,825: Fidelidade final: 0.9980 (F_qubit: 0.9882 * F_rota: 0.9980)
# ...
# 2025-08-13 14:41:22,252: Fidelidade do EPR 0->3: 0.999
# 2025-08-13 14:41:22,252: Fidelidade do EPR 3->6: 0.999
# 2025-08-13 14:41:22,252: Produto das fidelidades para rota [0, 3, 6]: 0.998001
# 2025-08-13 14:41:22,252: Fidelidade atual da rota: 0.998001
# 2025-08-13 14:41:22,253: Fidelidade final: 0.9980 (F_qubit: 0.8953 * F_rota: 0.9980)
# 2025-08-13 14:41:22,253: Fidelidade do EPR 0->3: 0.998001
# 2025-08-13 14:41:22,254: Fidelidade do EPR 3->6: 0.998001
# 2025-08-13 14:41:22,254: Produto das fidelidades para rota [0, 3, 6]: 0.996005996001
# 2025-08-13 14:41:22,254: Fidelidade atual da rota: 0.996005996001
# 2025-08-13 14:41:22,254: Fidelidade final: 0.9960 (F_qubit: 0.9751 * F_rota: 0.9960)
# 2025-08-13 14:41:22,255: Fidelidade do EPR 0->3: 0.997002999
# 2025-08-13 14:41:22,255: Fidelidade do EPR 3->6: 0.997002999
# 2025-08-13 14:41:22,256: Produto das fidelidades para rota [0, 3, 6]: 0.994014980014994
# 2025-08-13 14:41:22,256: Fidelidade atual da rota: 0.994014980014994
# 2025-08-13 14:41:22,257: Fidelidade final: 0.9940 (F_qubit: 0.9091 * F_rota: 0.9940)
# 2025-08-13 14:41:22,257: Foram utilizados 8 pares EPRs ao longo da transmissão.
# 2025-08-13 14:41:22,258: Transmissão de 4 qubits entre 0 e 6 concluída com sucesso.
# 2025-08-13 14:41:22,258: Servidor devolveu 0 qubits para o cliente.
# 2025-08-13 14:41:22,259: Qubit 265 devolvido para o cliente - Estado: 0, Fase: 1
# 2025-08-13 14:41:22,259: Qubit 378 devolvido para o cliente - Estado: 0, Fase: 1
# 2025-08-13 14:41:22,259: Qubit 483 devolvido para o cliente - Estado: 1, Fase: 1
# 2025-08-13 14:41:22,260: Qubit 235 devolvido para o cliente - Estado: 1, Fase: -1
# 2025-08-13 14:41:22,260: Cliente aplicou a decodificação Clifford no qubit 265.
# 2025-08-13 14:41:22,260: Cliente aplicou a decodificação Clifford no qubit 378.
# 2025-08-13 14:41:22,261: Cliente aplicou a decodificação Clifford no qubit 483.
# 2025-08-13 14:41:22,261: Cliente aplicou a decodificação Clifford no qubit 235.
# 2025-08-13 14:41:22,261: Protocolo concluído com sucesso. O cliente tem 4 qubits decodificados.
# 2025-08-13 14:41:22,261: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff8117730a0> adicionado ao canal.
# 2025-08-13 14:41:22,262: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f92a9450> adicionado ao canal.
# 2025-08-13 14:41:22,262: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8faff40> adicionado ao canal.
# 2025-08-13 14:41:22,263: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff80320a860> adicionado ao canal.
# 2025-08-13 14:41:22,264: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8fafd90> adicionado ao canal.
# 2025-08-13 14:41:22,264: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff803244310> adicionado ao canal.
# 2025-08-13 14:41:22,265: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8fafe50> adicionado ao canal.
# 2025-08-13 14:41:22,265: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8e84670> adicionado ao canal.
# 2025-08-13 14:41:22,266: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9bdde70> adicionado ao canal.
# 2025-08-13 14:41:22,267: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8e85150> adicionado ao canal.
# 2025-08-13 14:41:22,267: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8e87d90> adicionado ao canal.
# 2025-08-13 14:41:22,268: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8e84040> adicionado ao canal.
# 2025-08-13 14:41:22,268: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8e87a30> adicionado ao canal.
# 2025-08-13 14:41:22,269: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8e84a00> adicionado ao canal.
# 2025-08-13 14:41:22,269: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8e84f70> adicionado ao canal.
# 2025-08-13 14:41:22,270: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8e85bd0> adicionado ao canal.
# 2025-08-13 14:41:22,270: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8e84220> adicionado ao canal.
# 2025-08-13 14:41:22,271: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8e84130> adicionado ao canal.
# 2025-08-13 14:41:22,271: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8e84760> adicionado ao canal.
# 2025-08-13 14:41:22,272: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8e842b0> adicionado ao canal.
# 2025-08-13 14:41:22,272: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8e84370> adicionado ao canal.
# 2025-08-13 14:41:22,273: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8e84a30> adicionado ao canal.
# 2025-08-13 14:41:22,273: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8e87e20> adicionado ao canal.
# 2025-08-13 14:41:22,274: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f8e84430> adicionado ao canal.
# Época 9/10, Perda (Loss): 0.9961
# Executando simulação BQC para a época 9 com profundidade de circuito: 2
# Tempo de Operação: 2
# Pares EPRs adicionados
# 2025-08-13 14:41:29,207: Timeslot 99: Iniciando protocolo Andrew Childs entre Alice 6 e Bob 0.
# 2025-08-13 14:41:29,208: Limpando a memória do cliente (Alice) antes de iniciar o protocolo.
# 2025-08-13 14:41:29,209: Limpando a memória do servidor (Bob) antes de iniciar o protocolo.
# 2025-08-13 14:41:29,209: Cliente criou 4 qubits para a transmissão.
# 2025-08-13 14:41:29,209: Qubit 408 registrado no timeslot 99
# 2025-08-13 14:41:29,210: Qubit 631 registrado no timeslot 99
# 2025-08-13 14:41:29,210: Qubit 548 registrado no timeslot 99
# 2025-08-13 14:41:29,211: Qubit 459 registrado no timeslot 99
# 2025-08-13 14:41:29,211: Qubit 408 criado pelo Cliente - Estado: 0, Fase: 1
# 2025-08-13 14:41:29,212: Qubit 631 criado pelo Cliente - Estado: 0, Fase: 1
# 2025-08-13 14:41:29,212: Qubit 548 criado pelo Cliente - Estado: 0, Fase: 1
# 2025-08-13 14:41:29,214: Qubit 459 criado pelo Cliente - Estado: 0, Fase: 1
# 2025-08-13 14:41:29,215: Alice recebeu 4 qubits. Total: 4 qubits na memória.
# 2025-08-13 14:41:29,215: Instruções clássicas enviadas pelo Cliente: ['Y', 'X', 'X', 'Y']
# 2025-08-13 14:41:29,216: Timeslot 100: Buscando rota válida entre 6 e 0.
# 2025-08-13 14:41:29,217: Rota válida encontrada: [6, 3, 0]
# 2025-08-13 14:41:29,217: Rota calculada para o transporte: [6, 3, 0]
# 2025-08-13 14:41:29,218: Timeslot 100: Limpando pares EPRs residuais antes de iniciar o protocolo.
# 2025-08-13 14:41:29,218: Pares EPRs limpos no segmento 6 -> 3.
# 2025-08-13 14:41:29,219: Pares EPRs limpos no segmento 3 -> 0.
# 2025-08-13 14:41:29,219: Usando a rota fornecida: [6, 3, 0]
# 2025-08-13 14:41:29,220: Ida: Criando 4 pares EPRs no segmento 6 -> 3.
# 2025-08-13 14:41:29,220: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff8033f8c10> adicionado ao canal (6, 3).
# 2025-08-13 14:41:29,221: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9bddf30> adicionado ao canal (6, 3).
# 2025-08-13 14:41:29,221: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff8117730a0> adicionado ao canal (6, 3).
# 2025-08-13 14:41:29,222: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f88f2f20> adicionado ao canal (6, 3).
# 2025-08-13 14:41:29,222: Ida: Criando 4 pares EPRs no segmento 3 -> 0.
# 2025-08-13 14:41:29,223: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff8031df910> adicionado ao canal (3, 0).
# 2025-08-13 14:41:29,223: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f88f2f50> adicionado ao canal (3, 0).
# 2025-08-13 14:41:29,223: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f88f2ef0> adicionado ao canal (3, 0).
# 2025-08-13 14:41:29,224: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f88f35e0> adicionado ao canal (3, 0).
# 2025-08-13 14:41:29,225: Fidelidade do EPR 6->3: 1.0
# 2025-08-13 14:41:29,226: Fidelidade do EPR 3->0: 1.0
# 2025-08-13 14:41:29,226: Produto das fidelidades para rota [6, 3, 0]: 1.0
# 2025-08-13 14:41:29,226: Fidelidade atual da rota: 1.0
# 2025-08-13 14:41:29,227: Fidelidade final: 1.0000 (F_qubit: 0.9163 * F_rota: 1.0000)
# 2025-08-13 14:41:29,228: Fidelidade do EPR 6->3: 0.999
# 2025-08-13 14:41:29,229: Fidelidade do EPR 3->0: 0.999
# 2025-08-13 14:41:29,230: Produto das fidelidades para rota [6, 3, 0]: 0.998001
# 2025-08-13 14:41:29,230: Fidelidade atual da rota: 0.998001
# 2025-08-13 14:41:29,231: Fidelidade final: 0.9980 (F_qubit: 0.9942 * F_rota: 0.9980)
# 2025-08-13 14:41:29,231: Fidelidade do EPR 6->3: 0.998001
# 2025-08-13 14:41:29,232: Fidelidade do EPR 3->0: 0.998001
# 2025-08-13 14:41:29,233: Produto das fidelidades para rota [6, 3, 0]: 0.996005996001
# 2025-08-13 14:41:29,233: Fidelidade atual da rota: 0.996005996001
# 2025-08-13 14:41:29,234: Fidelidade final: 0.9960 (F_qubit: 0.9858 * F_rota: 0.9960)
# 2025-08-13 14:41:29,235: Fidelidade do EPR 6->3: 0.997002999
# 2025-08-13 14:41:29,235: Fidelidade do EPR 3->0: 0.997002999
# 2025-08-13 14:41:29,236: Produto das fidelidades para rota [6, 3, 0]: 0.994014980014994
# 2025-08-13 14:41:29,236: Fidelidade atual da rota: 0.994014980014994
# 2025-08-13 14:41:29,237: Fidelidade final: 0.9940 (F_qubit: 0.9697 * F_rota: 0.9940)
# 2025-08-13 14:41:29,237: Foram utilizados 8 pares EPRs ao longo da transmissão.
# 2025-08-13 14:41:29,238: Transmissão de 4 qubits entre 6 e 0 concluída com sucesso.
# 2025-08-13 14:41:29,238: Cliente enviou 4 qubits para o Servidor.
# 2025-08-13 14:41:29,239: Servidor tem 4 qubits na memória após a recepção.
# 2025-08-13 14:41:29,239: Timeslot 105: Servidor aplicando operações nos qubits.
# 2025-08-13 14:41:29,240: Timeslot 106: Servidor aplicando operações nos qubits.
# 2025-08-13 14:41:29,241: Servidor aplicou as operações instruídas pelo Cliente nos qubits.
# 2025-08-13 14:41:29,242: Qubit 408 após operações de Servidor - Estado: 1, Fase: -1
# 2025-08-13 14:41:29,243: Qubit 631 após operações de Servidor - Estado: 1, Fase: 1
# 2025-08-13 14:41:29,244: Qubit 548 após operações de Servidor - Estado: 1, Fase: 1
# 2025-08-13 14:41:29,244: Qubit 459 após operações de Servidor - Estado: 1, Fase: -1
# 2025-08-13 14:41:29,244: Limpando a memória do cliente antes de receber os qubits devolvidos.
# 2025-08-13 14:41:29,245: Usando a rota fornecida: [0, 3, 6]
# 2025-08-13 14:41:29,246: Volta: Criando 4 pares EPRs no segmento 0 -> 3.
# 2025-08-13 14:41:29,246: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff8117730a0> adicionado ao canal (0, 3).
# 2025-08-13 14:41:29,247: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff8033f8c10> adicionado ao canal (0, 3).
# 2025-08-13 14:41:29,247: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f88f3640> adicionado ao canal (0, 3).
# 2025-08-13 14:41:29,248: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f88f2ec0> adicionado ao canal (0, 3).
# 2025-08-13 14:41:29,248: Volta: Criando 4 pares EPRs no segmento 3 -> 6.
# 2025-08-13 14:41:29,249: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f92a9450> adicionado ao canal (3, 6).
# 2025-08-13 14:41:29,249: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f88f30a0> adicionado ao canal (3, 6).
# 2025-08-13 14:41:29,251: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f88f3490> adicionado ao canal (3, 6).
# 2025-08-13 14:41:29,252: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f88f35b0> adicionado ao canal (3, 6).
# 2025-08-13 14:41:29,252: Fidelidade do EPR 0->3: 1.0
# 2025-08-13 14:41:29,253: Fidelidade do EPR 3->6: 1.0
# 2025-08-13 14:41:29,253: Produto das fidelidades para rota [0, 3, 6]: 1.0
# 2025-08-13 14:41:29,254: Fidelidade atual da rota: 1.0
# 2025-08-13 14:41:29,255: Fidelidade final: 1.0000 (F_qubit: 0.9109 * F_rota: 1.0000)
# 2025-08-13 14:41:29,255: Fidelidade do EPR 0->3: 0.999
# 2025-08-13 14:41:29,255: Fidelidade do EPR 3->6: 0.999
# 2025-08-13 14:41:29,255: Produto das fidelidades para rota [0, 3, 6]: 0.998001
# 2025-08-13 14:41:29,255: Fidelidade atual da rota: 0.998001
# 2025-08-13 14:41:29,256: Fidelidade final: 0.9980 (F_qubit: 0.9883 * F_rota: 0.9980)
# 2025-08-13 14:41:29,256: Fidelidade do EPR 0->3: 0.998001
# 2025-08-13 14:41:29,256: Fidelidade do EPR 3->6: 0.998001
# 2025-08-13 14:41:29,256: Produto das fidelidades para rota [0, 3, 6]: 0.996005996001
# 2025-08-13 14:41:29,257: Fidelidade atual da rota: 0.996005996001
# 2025-08-13 14:41:29,257: Fidelidade final: 0.9960 (F_qubit: 0.9799 * F_rota: 0.9960)
# 2025-08-13 14:41:29,257: Fidelidade do EPR 0->3: 0.997002999
# 2025-08-13 14:41:29,257: Fidelidade do EPR 3->6: 0.997002999
# 2025-08-13 14:41:29,258: Produto das fidelidades para rota [0, 3, 6]: 0.994014980014994
# 2025-08-13 14:41:29,258: Fidelidade atual da rota: 0.994014980014994
# 2025-08-13 14:41:29,258: Fidelidade final: 0.9940 (F_qubit: 0.9639 * F_rota: 0.9940)
# 2025-08-13 14:41:29,259: Foram utilizados 8 pares EPRs ao longo da transmissão.
# 2025-08-13 14:41:29,259: Transmissão de 4 qubits entre 0 e 6 concluída com sucesso.
# 2025-08-13 14:41:29,259: Servidor devolveu 0 qubits para o cliente.
# 2025-08-13 14:41:29,259: Qubit 408 devolvido para o cliente - Estado: 1, Fase: -1
# 2025-08-13 14:41:29,259: Qubit 631 devolvido para o cliente - Estado: 1, Fase: 1
# 2025-08-13 14:41:29,260: Qubit 548 devolvido para o cliente - Estado: 1, Fase: 1
# 2025-08-13 14:41:29,260: Qubit 459 devolvido para o cliente - Estado: 1, Fase: -1
# 2025-08-13 14:41:29,260: Cliente aplicou a decodificação Clifford no qubit 408.
# 2025-08-13 14:41:29,260: Cliente aplicou a decodificação Clifford no qubit 631.
# 2025-08-13 14:41:29,260: Cliente aplicou a decodificação Clifford no qubit 548.
# 2025-08-13 14:41:29,261: Cliente aplicou a decodificação Clifford no qubit 459.
# 2025-08-13 14:41:29,261: Protocolo concluído com sucesso. O cliente tem 4 qubits decodificados.
# 2025-08-13 14:41:29,261: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff8117730a0> adicionado ao canal.
# 2025-08-13 14:41:29,261: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff8033f8e50> adicionado ao canal.
# 2025-08-13 14:41:29,262: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9bddf30> adicionado ao canal.
# 2025-08-13 14:41:29,262: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff8033f9ea0> adicionado ao canal.
# 2025-08-13 14:41:29,262: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff8031df910> adicionado ao canal.
# 2025-08-13 14:41:29,263: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f88f3640> adicionado ao canal.
# 2025-08-13 14:41:29,263: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff8119eaad0> adicionado ao canal.
# 2025-08-13 14:41:29,264: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9306020> adicionado ao canal.
# 2025-08-13 14:41:29,265: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9307b50> adicionado ao canal.
# 2025-08-13 14:41:29,265: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f88f3250> adicionado ao canal.
# 2025-08-13 14:41:29,266: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f88f30a0> adicionado ao canal.
# 2025-08-13 14:41:29,267: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f88f3160> adicionado ao canal.
# 2025-08-13 14:41:29,268: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f88f3310> adicionado ao canal.
# 2025-08-13 14:41:29,270: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f88f2f80> adicionado ao canal.
# 2025-08-13 14:41:29,270: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f88f2ef0> adicionado ao canal.
# 2025-08-13 14:41:29,271: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f88f35b0> adicionado ao canal.
# 2025-08-13 14:41:29,271: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9304f40> adicionado ao canal.
# 2025-08-13 14:41:29,272: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f93048e0> adicionado ao canal.
# 2025-08-13 14:41:29,272: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9304730> adicionado ao canal.
# 2025-08-13 14:41:29,272: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f88f3040> adicionado ao canal.
# 2025-08-13 14:41:29,273: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f88f31f0> adicionado ao canal.
# 2025-08-13 14:41:29,273: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f88f37f0> adicionado ao canal.
# 2025-08-13 14:41:29,273: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f9306fe0> adicionado ao canal.
# 2025-08-13 14:41:29,273: Par EPR <quantumnet.objects.epr.Epr object at 0x7ff7f88f38b0> adicionado ao canal.
# Época 10/10, Perda (Loss): 0.9680
# Executando simulação BQC para a época 10 com profundidade de circuito: 2
# Tempo de Operação: 2
# Pares EPRs adicionados

# %% [markdown]
# # Avaliação
# - Primeiro ele, Faz previsão no conjunto de teste, sem atualizar o modelo.
# - Transforma saída em probabilidade e decide se é classe 0 ou 1.
# - Prepara os resultados para análise (cálculo das métricas).
# # Métricas
# - Acurácia: porcentagem de previsões corretas (tanto verdadeiros positivos quanto verdadeiros negativos).
#
# - Precisão: proporção de previsões positivas que estavam corretas (foca em evitar falsos positivos).
#
# - Recall: proporção de casos positivos corretamente identificados (foca em evitar falsos negativos).

# %%
# --- 7. Avaliação do Modelo ---
print("\nIniciando a avaliação final...")
model.eval()

with torch.no_grad():
    X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
    outputs = model(X_test_tensor)
    probabilities = torch.softmax(outputs, dim=1)
    y_pred = torch.argmax(probabilities, dim=1).numpy()

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro')
recall = recall_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred, average='macro')

print("\n--- MÉTRICAS DE AVALIAÇÃO (MULTICLASSE com V2) ---")
print(f"Acurácia: {accuracy:.2f}")
print(f"Precisão (Macro): {precision:.2f}")
print(f"Recall (Macro): {recall:.2f}")
print(f"F1-Score (Macro): {f1:.2f}")
# Out:
# Iniciando a avaliação final...
#
# --- MÉTRICAS DE AVALIAÇÃO (MULTICLASSE com V2) ---
# Acurácia: 0.80
# Precisão (Macro): 0.88
# Recall (Macro): 0.80
# F1-Score (Macro): 0.81

# %% [markdown]
# ## Conclusões e próximos passos
#
# - O experimento de Blind Quantum Computing foi executado com sucesso.
# - Próximos passos podem incluir: testar outros datasets, aprimorar o circuito quântico, ou analisar a segurança do protocolo.
